# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # TODO: Implement Function
    
    source_ids = [[source_vocab_to_int.get(word) for word in line.split()] for line in source_text.split('\n')]
    target_ids = [[target_vocab_to_int.get(word) for word in line.split()] + [target_vocab_to_int['<EOS>']] for line in target_text.split('\n')]
    
   
    return (source_ids, target_ids)



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.3.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    # TODO: Implement Function
    
    
    input_data = tf.placeholder(dtype=tf.int32, shape=[None,None], name='input')
    targets = tf.placeholder(dtype=tf.int32, shape=[None,None], name='targets')
    
    learning_rate = tf.placeholder(dtype=tf.float32, name='learning_rate')
    keep_probability = tf.placeholder(dtype=tf.float32, name='keep_prob')
    
    target_sequence_length = tf.placeholder(tf.int32, (None,), name='target_sequence_length')
    max_target_len =  tf.reduce_max(target_sequence_length , name='max_target_len')
    source_sequence_length = tf.placeholder(tf.int32, (None,), name='source_sequence_length')
    
    
    return input_data, targets, learning_rate, keep_probability, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/opt/conda/lib/python3.6/runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/opt/conda/lib/python3.6/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/opt/conda/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start\n    self.io_loop.start()', 'File "/opt/conda/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/opt/conda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events\n    self._handle_recv()', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback\n    callback(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell\n    raw_cell, store_history, silent, shell_futures)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2907, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-7-cf9b5ffdc126>", line 27, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/workspace/DeepLearning_ND/Udacity-Deep-Learning-Nanodegree-master/language-translation/problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py", line 175, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py", line 144, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py", line 101, in __init__\n    stack = [s.strip() for s in traceback.format_stack()]']
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/opt/conda/lib/python3.6/runpy.py", line 193, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/opt/conda/lib/python3.6/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/opt/conda/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 497, in start\n    self.io_loop.start()', 'File "/opt/conda/lib/python3.6/site-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/opt/conda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events\n    self._handle_recv()', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/opt/conda/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback\n    callback(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/opt/conda/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell\n    raw_cell, store_history, silent, shell_futures)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2907, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-7-cf9b5ffdc126>", line 27, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/workspace/DeepLearning_ND/Udacity-Deep-Learning-Nanodegree-master/language-translation/problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py", line 175, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py", line 144, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/opt/conda/lib/python3.6/site-packages/tensorflow/python/util/tf_should_use.py", line 101, in __init__\n    stack = [s.strip() for s in traceback.format_stack()]']
# ==================================
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    
    # remove the last word id from each batch in target_data 
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    
    # concat the GO ID to the begining of each batch
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)

    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    
    # Embed the encoder input 
    enc_embed_input = tf.contrib.layers.embed_sequence(ids=rnn_inputs,
                                                       vocab_size=source_vocab_size, 
                                                       embed_dim=encoding_embedding_size)
    # LSTM cell
    def lstm_cell(rnn_size):
        return  tf.contrib.rnn.LSTMCell(rnn_size,
                                        initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
    
    # Stacked LSTM 
    stacked_lstm = tf.contrib.rnn.MultiRNNCell([lstm_cell(rnn_size) for _ in range(num_layers)])
    enc_cell = tf.contrib.rnn.DropoutWrapper(cell = stacked_lstm,
                                             input_keep_prob= 1.0, 
                                             output_keep_prob = keep_prob, 
                                             input_size= None,  
                                             seed= 2 )
    
    # Create the recurrent neural network and perform fully dynamic unrolling of inputs
    enc_output, enc_state = tf.nn.dynamic_rnn(cell = enc_cell, 
                                              inputs = enc_embed_input, 
                                              sequence_length=source_sequence_length,
                                              initial_state=None,
                                              dtype=tf.float32)
    
    return enc_output, enc_state


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    
    
     # Helper for the training process. Used by BasicDecoder to read inputs
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs = dec_embed_input,
                                                        sequence_length = target_sequence_length,
                                                        time_major=False)
    
    
    # Basic decoder
    training_decoder = tf.contrib.seq2seq.BasicDecoder(cell = dec_cell, 
                                                       helper = training_helper,
                                                       initial_state = encoder_state, 
                                                       output_layer = output_layer) 
        
    # Perform dynamic decoding using the decoder
    training_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(decoder = training_decoder,
                                                                   impute_finished = True,
                                                                   maximum_iterations = max_summary_length)
    
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    
    # Helper for the inference process.
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
    
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(embedding = dec_embeddings,
                                                                start_tokens = start_tokens, 
                                                                end_token = end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(cell = dec_cell,
                                                        helper = inference_helper,
                                                        initial_state = encoder_state,
                                                        output_layer = output_layer)
        
    # Perform dynamic decoding using the decoder
    inference_decoder_output, _, _ = tf.contrib.seq2seq.dynamic_decode(decoder = inference_decoder, 
                                                                    impute_finished = True,
                                                                    maximum_iterations = max_target_sequence_length)
         
    # Note : vocab_size, keep_prob are of no use here

    
    return inference_decoder_output
    
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    
    # Decoder embedding : Embed the target sequence
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    
    # Construct the decoder LSTM cell 
    def lstm_cell(rnn_size):
        return  tf.contrib.rnn.LSTMCell(rnn_size,
                                        initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
    
    # Stacked LSTM 
    stacked_lstm = tf.contrib.rnn.MultiRNNCell([lstm_cell(rnn_size) for _ in range(num_layers)])
    dec_cell = tf.contrib.rnn.DropoutWrapper(cell = stacked_lstm,
                                             input_keep_prob= 1.0,           
                                             output_keep_prob = keep_prob,  
                                             input_size= None,  
                                             seed= 2 )
    

    
    # Create an Dense output layer to map the outputs of the decoder to the elements of our vocabulary  
    output_layer = Dense(target_vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))
    
    
    with tf.variable_scope("decode"):
    
        # Use decoding_layer_train() function to get the training logits
        training_logits = decoding_layer_train(encoder_state = encoder_state , 
                                               dec_cell = dec_cell , 
                                               dec_embed_input = dec_embed_input , 
                                               target_sequence_length = target_sequence_length , 
                                               max_summary_length = max_target_sequence_length , 
                                               output_layer = output_layer , 
                                               keep_prob = keep_prob )
    
    with tf.variable_scope("decode", reuse=True):
    
        # Use decoding_layer_infer() function to get the inference logits
        inference_logits = decoding_layer_infer(encoder_state = encoder_state ,
                                                dec_cell =  dec_cell ,
                                                dec_embeddings = dec_embeddings ,
                                                start_of_sequence_id = target_vocab_to_int['<GO>'],
                                                end_of_sequence_id = target_vocab_to_int['<EOS>'],
                                                max_target_sequence_length =  max_target_sequence_length ,
                                                vocab_size =  target_vocab_size ,
                                                output_layer = output_layer ,
                                                batch_size = batch_size ,
                                                keep_prob = keep_prob)
    

        
    
    return (training_logits, inference_logits)



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function

    # Encode the input data. We'll ignore the encoder output, but use the state
    _, enc_state = encoding_layer(rnn_inputs = input_data , 
                                  rnn_size = rnn_size , 
                                  num_layers = num_layers , 
                                  keep_prob = keep_prob ,
                                  source_sequence_length = source_sequence_length ,
                                  source_vocab_size = source_vocab_size , 
                                  encoding_embedding_size = enc_embedding_size)
    
    # Prepare the target sequences we'll feed to the decoder in training mode
    dec_input = process_decoder_input(target_data = target_data ,
                                      target_vocab_to_int =  target_vocab_to_int,
                                      batch_size = batch_size)
    
    # Pass encoder state and decoder inputs to the decoders
    training_decoder_output, inference_decoder_output =  decoding_layer(dec_input = dec_input, 
                                                                        encoder_state = enc_state,
                                                                        target_sequence_length = target_sequence_length ,
                                                                        max_target_sequence_length = max_target_sentence_length,
                                                                        rnn_size = rnn_size,
                                                                        num_layers = num_layers,
                                                                        target_vocab_to_int = target_vocab_to_int, 
                                                                        target_vocab_size = target_vocab_size,
                                                                        batch_size = batch_size, 
                                                                        keep_prob = keep_prob,
                                                                        decoding_embedding_size = dec_embedding_size )
    
    return training_decoder_output, inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 32
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 150
decoding_embedding_size = 150
# Learning Rate
learning_rate = 0.001
# Dropout Keep Probability
keep_probability = 0.8
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
# Little add-on to enhance the monitoring
import time
start_time = time.time()

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f} elapsed_time = {:.1f} min'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss,
                              (time.time()-start_time)/60)) # Little add-on to enhance the monitoring

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
    
    # Little add-on to enhance the monitoring       
    train_time = time.time() - start_time
    print("\nTotal Training Time " ,  train_time)
# Out:
# Epoch   0 Batch   10/4308 - Train Accuracy: 0.2625, Validation Accuracy: 0.2105, Loss: 4.4309 elapsed_time = 0.1 min
# Epoch   0 Batch   20/4308 - Train Accuracy: 0.2984, Validation Accuracy: 0.2385, Loss: 3.6702 elapsed_time = 0.1 min
# Epoch   0 Batch   30/4308 - Train Accuracy: 0.2747, Validation Accuracy: 0.2714, Loss: 3.5063 elapsed_time = 0.1 min
# Epoch   0 Batch   40/4308 - Train Accuracy: 0.2865, Validation Accuracy: 0.2895, Loss: 3.3530 elapsed_time = 0.2 min
# Epoch   0 Batch   50/4308 - Train Accuracy: 0.3482, Validation Accuracy: 0.3109, Loss: 2.9258 elapsed_time = 0.2 min
# Epoch   0 Batch   60/4308 - Train Accuracy: 0.3810, Validation Accuracy: 0.3207, Loss: 2.7903 elapsed_time = 0.2 min
# Epoch   0 Batch   70/4308 - Train Accuracy: 0.3470, Validation Accuracy: 0.3487, Loss: 2.9970 elapsed_time = 0.3 min
# Epoch   0 Batch   80/4308 - Train Accuracy: 0.4672, Validation Accuracy: 0.3980, Loss: 2.6247 elapsed_time = 0.3 min
# Epoch   0 Batch   90/4308 - Train Accuracy: 0.3931, Validation Accuracy: 0.3980, Loss: 2.7399 elapsed_time = 0.4 min
# Epoch   0 Batch  100/4308 - Train Accuracy: 0.4424, Validation Accuracy: 0.3865, Loss: 2.5704 elapsed_time = 0.4 min
# Epoch   0 Batch  110/4308 - Train Accuracy: 0.4030, Validation Accuracy: 0.3717, Loss: 2.4662 elapsed_time = 0.4 min
# Epoch   0 Batch  120/4308 - Train Accuracy: 0.3559, Validation Accuracy: 0.3470, Loss: 2.4491 elapsed_time = 0.5 min
# Epoch   0 Batch  130/4308 - Train Accuracy: 0.4266, Validation Accuracy: 0.4128, Loss: 2.3791 elapsed_time = 0.5 min
# Epoch   0 Batch  140/4308 - Train Accuracy: 0.3781, Validation Accuracy: 0.3405, Loss: 2.2570 elapsed_time = 0.5 min
# Epoch   0 Batch  150/4308 - Train Accuracy: 0.4641, Validation Accuracy: 0.3898, Loss: 2.0835 elapsed_time = 0.6 min
# Epoch   0 Batch  160/4308 - Train Accuracy: 0.4359, Validation Accuracy: 0.3898, Loss: 2.2182 elapsed_time = 0.6 min
# Epoch   0 Batch  170/4308 - Train Accuracy: 0.4859, Validation Accuracy: 0.3947, Loss: 1.9300 elapsed_time = 0.6 min
# Epoch   0 Batch  180/4308 - Train Accuracy: 0.3438, Validation Accuracy: 0.3388, Loss: 2.2328 elapsed_time = 0.7 min
# Epoch   0 Batch  190/4308 - Train Accuracy: 0.4046, Validation Accuracy: 0.3651, Loss: 2.0659 elapsed_time = 0.7 min
# Epoch   0 Batch  200/4308 - Train Accuracy: 0.4122, Validation Accuracy: 0.3322, Loss: 1.8667 elapsed_time = 0.8 min
# Epoch   0 Batch  210/4308 - Train Accuracy: 0.4457, Validation Accuracy: 0.3832, Loss: 1.9162 elapsed_time = 0.8 min
# Epoch   0 Batch  220/4308 - Train Accuracy: 0.4046, Validation Accuracy: 0.3931, Loss: 2.0193 elapsed_time = 0.8 min
# Epoch   0 Batch  230/4308 - Train Accuracy: 0.3684, Validation Accuracy: 0.3882, Loss: 1.9767 elapsed_time = 0.9 min
# Epoch   0 Batch  240/4308 - Train Accuracy: 0.4013, Validation Accuracy: 0.3470, Loss: 1.8016 elapsed_time = 0.9 min
# Epoch   0 Batch  250/4308 - Train Accuracy: 0.4079, Validation Accuracy: 0.4112, Loss: 1.7731 elapsed_time = 0.9 min
# Epoch   0 Batch  260/4308 - Train Accuracy: 0.3503, Validation Accuracy: 0.3618, Loss: 1.7825 elapsed_time = 1.0 min
# Epoch   0 Batch  270/4308 - Train Accuracy: 0.3676, Validation Accuracy: 0.4013, Loss: 1.6532 elapsed_time = 1.0 min
# Epoch   0 Batch  280/4308 - Train Accuracy: 0.4219, Validation Accuracy: 0.3865, Loss: 1.7843 elapsed_time = 1.1 min
# Epoch   0 Batch  290/4308 - Train Accuracy: 0.4441, Validation Accuracy: 0.3421, Loss: 1.5425 elapsed_time = 1.1 min
# Epoch   0 Batch  300/4308 - Train Accuracy: 0.3438, Validation Accuracy: 0.3125, Loss: 1.6399 elapsed_time = 1.1 min
# Epoch   0 Batch  310/4308 - Train Accuracy: 0.3980, Validation Accuracy: 0.3750, Loss: 1.5010 elapsed_time = 1.2 min
# Epoch   0 Batch  320/4308 - Train Accuracy: 0.3536, Validation Accuracy: 0.3405, Loss: 1.4498 elapsed_time = 1.2 min
# Epoch   0 Batch  330/4308 - Train Accuracy: 0.3520, Validation Accuracy: 0.3224, Loss: 1.5340 elapsed_time = 1.2 min
# Epoch   0 Batch  340/4308 - Train Accuracy: 0.3766, Validation Accuracy: 0.3438, Loss: 1.5279 elapsed_time = 1.3 min
# Epoch   0 Batch  350/4308 - Train Accuracy: 0.3405, Validation Accuracy: 0.3553, Loss: 1.5009 elapsed_time = 1.3 min
# Epoch   0 Batch  360/4308 - Train Accuracy: 0.3767, Validation Accuracy: 0.3470, Loss: 1.5259 elapsed_time = 1.3 min
# Epoch   0 Batch  370/4308 - Train Accuracy: 0.4145, Validation Accuracy: 0.3569, Loss: 1.3057 elapsed_time = 1.4 min
# Epoch   0 Batch  380/4308 - Train Accuracy: 0.4234, Validation Accuracy: 0.3602, Loss: 1.1996 elapsed_time = 1.4 min
# Epoch   0 Batch  390/4308 - Train Accuracy: 0.3799, Validation Accuracy: 0.3569, Loss: 1.3908 elapsed_time = 1.5 min
# Epoch   0 Batch  400/4308 - Train Accuracy: 0.4408, Validation Accuracy: 0.4490, Loss: 1.4694 elapsed_time = 1.5 min
# Epoch   0 Batch  410/4308 - Train Accuracy: 0.4844, Validation Accuracy: 0.4293, Loss: 1.1723 elapsed_time = 1.5 min
# Epoch   0 Batch  420/4308 - Train Accuracy: 0.3931, Validation Accuracy: 0.4112, Loss: 1.4424 elapsed_time = 1.6 min
# Epoch   0 Batch  430/4308 - Train Accuracy: 0.5000, Validation Accuracy: 0.3914, Loss: 1.4096 elapsed_time = 1.6 min
# Epoch   0 Batch  440/4308 - Train Accuracy: 0.4188, Validation Accuracy: 0.3503, Loss: 1.3208 elapsed_time = 1.7 min
# Epoch   0 Batch  450/4308 - Train Accuracy: 0.4172, Validation Accuracy: 0.4178, Loss: 1.1811 elapsed_time = 1.7 min
# Epoch   0 Batch  460/4308 - Train Accuracy: 0.3997, Validation Accuracy: 0.3997, Loss: 1.2496 elapsed_time = 1.7 min
# Epoch   0 Batch  470/4308 - Train Accuracy: 0.4424, Validation Accuracy: 0.4852, Loss: 1.3373 elapsed_time = 1.8 min
# Epoch   0 Batch  480/4308 - Train Accuracy: 0.4885, Validation Accuracy: 0.4720, Loss: 1.1358 elapsed_time = 1.8 min
# Epoch   0 Batch  490/4308 - Train Accuracy: 0.5000, Validation Accuracy: 0.4688, Loss: 1.0991 elapsed_time = 1.8 min
# Epoch   0 Batch  500/4308 - Train Accuracy: 0.4422, Validation Accuracy: 0.4441, Loss: 1.1201 elapsed_time = 1.9 min
# Epoch   0 Batch  510/4308 - Train Accuracy: 0.5342, Validation Accuracy: 0.4211, Loss: 0.9876 elapsed_time = 1.9 min
# Epoch   0 Batch  520/4308 - Train Accuracy: 0.4622, Validation Accuracy: 0.4359, Loss: 1.2470 elapsed_time = 1.9 min
# Epoch   0 Batch  530/4308 - Train Accuracy: 0.4819, Validation Accuracy: 0.4539, Loss: 1.1446 elapsed_time = 2.0 min
# Epoch   0 Batch  540/4308 - Train Accuracy: 0.3964, Validation Accuracy: 0.4737, Loss: 1.1293 elapsed_time = 2.0 min
# Epoch   0 Batch  550/4308 - Train Accuracy: 0.5047, Validation Accuracy: 0.4819, Loss: 1.0123 elapsed_time = 2.1 min
# Epoch   0 Batch  560/4308 - Train Accuracy: 0.5477, Validation Accuracy: 0.4605, Loss: 1.0117 elapsed_time = 2.1 min
# Epoch   0 Batch  570/4308 - Train Accuracy: 0.5493, Validation Accuracy: 0.4589, Loss: 1.0611 elapsed_time = 2.1 min
# Epoch   0 Batch  580/4308 - Train Accuracy: 0.4227, Validation Accuracy: 0.4556, Loss: 0.9952 elapsed_time = 2.2 min
# Epoch   0 Batch  590/4308 - Train Accuracy: 0.5119, Validation Accuracy: 0.4868, Loss: 1.0232 elapsed_time = 2.2 min
# Epoch   0 Batch  600/4308 - Train Accuracy: 0.4750, Validation Accuracy: 0.4770, Loss: 0.9196 elapsed_time = 2.2 min
# Epoch   0 Batch  610/4308 - Train Accuracy: 0.5312, Validation Accuracy: 0.4490, Loss: 1.0274 elapsed_time = 2.3 min
# Epoch   0 Batch  620/4308 - Train Accuracy: 0.4885, Validation Accuracy: 0.4770, Loss: 1.0128 elapsed_time = 2.3 min
# Epoch   0 Batch  630/4308 - Train Accuracy: 0.3684, Validation Accuracy: 0.4918, Loss: 1.0740 elapsed_time = 2.4 min
# Epoch   0 Batch  640/4308 - Train Accuracy: 0.4479, Validation Accuracy: 0.4753, Loss: 0.9317 elapsed_time = 2.4 min
# Epoch   0 Batch  650/4308 - Train Accuracy: 0.4719, Validation Accuracy: 0.4967, Loss: 0.8643 elapsed_time = 2.4 min
# Epoch   0 Batch  660/4308 - Train Accuracy: 0.4500, Validation Accuracy: 0.4836, Loss: 0.9485 elapsed_time = 2.5 min
# Epoch   0 Batch  670/4308 - Train Accuracy: 0.4792, Validation Accuracy: 0.4918, Loss: 0.9172 elapsed_time = 2.5 min
# Epoch   0 Batch  680/4308 - Train Accuracy: 0.5559, Validation Accuracy: 0.4803, Loss: 1.0124 elapsed_time = 2.5 min
# Epoch   0 Batch  690/4308 - Train Accuracy: 0.4875, Validation Accuracy: 0.4934, Loss: 0.8883 elapsed_time = 2.6 min
# Epoch   0 Batch  700/4308 - Train Accuracy: 0.6031, Validation Accuracy: 0.4984, Loss: 0.8401 elapsed_time = 2.6 min
# Epoch   0 Batch  710/4308 - Train Accuracy: 0.4803, Validation Accuracy: 0.5049, Loss: 0.9326 elapsed_time = 2.6 min
# Epoch   0 Batch  720/4308 - Train Accuracy: 0.5806, Validation Accuracy: 0.4984, Loss: 0.8246 elapsed_time = 2.7 min
# Epoch   0 Batch  730/4308 - Train Accuracy: 0.4828, Validation Accuracy: 0.4984, Loss: 0.9878 elapsed_time = 2.7 min
# Epoch   0 Batch  740/4308 - Train Accuracy: 0.5891, Validation Accuracy: 0.5181, Loss: 0.8255 elapsed_time = 2.8 min
# Epoch   0 Batch  750/4308 - Train Accuracy: 0.5280, Validation Accuracy: 0.4737, Loss: 0.9101 elapsed_time = 2.8 min
# Epoch   0 Batch  760/4308 - Train Accuracy: 0.5461, Validation Accuracy: 0.5247, Loss: 0.8921 elapsed_time = 2.8 min
# Epoch   0 Batch  770/4308 - Train Accuracy: 0.5226, Validation Accuracy: 0.4967, Loss: 0.9035 elapsed_time = 2.9 min
# Epoch   0 Batch  780/4308 - Train Accuracy: 0.5230, Validation Accuracy: 0.4967, Loss: 0.8426 elapsed_time = 2.9 min
# Epoch   0 Batch  790/4308 - Train Accuracy: 0.5434, Validation Accuracy: 0.5049, Loss: 0.8908 elapsed_time = 2.9 min
# Epoch   0 Batch  800/4308 - Train Accuracy: 0.5594, Validation Accuracy: 0.4951, Loss: 0.7318 elapsed_time = 3.0 min
# Epoch   0 Batch  810/4308 - Train Accuracy: 0.5453, Validation Accuracy: 0.5115, Loss: 0.8137 elapsed_time = 3.0 min
# Epoch   0 Batch  820/4308 - Train Accuracy: 0.6141, Validation Accuracy: 0.5049, Loss: 0.7819 elapsed_time = 3.0 min
# Epoch   0 Batch  830/4308 - Train Accuracy: 0.5234, Validation Accuracy: 0.4655, Loss: 0.8344 elapsed_time = 3.1 min
# Epoch   0 Batch  840/4308 - Train Accuracy: 0.5181, Validation Accuracy: 0.4836, Loss: 0.8472 elapsed_time = 3.1 min
# Epoch   0 Batch  850/4308 - Train Accuracy: 0.4826, Validation Accuracy: 0.5132, Loss: 0.8701 elapsed_time = 3.2 min
# Epoch   0 Batch  860/4308 - Train Accuracy: 0.5125, Validation Accuracy: 0.5197, Loss: 0.8261 elapsed_time = 3.2 min
# Epoch   0 Batch  870/4308 - Train Accuracy: 0.5391, Validation Accuracy: 0.4984, Loss: 0.8015 elapsed_time = 3.2 min
# Epoch   0 Batch  880/4308 - Train Accuracy: 0.5797, Validation Accuracy: 0.5148, Loss: 0.7689 elapsed_time = 3.3 min
# Epoch   0 Batch  890/4308 - Train Accuracy: 0.5955, Validation Accuracy: 0.5345, Loss: 0.8051 elapsed_time = 3.3 min
# Epoch   0 Batch  900/4308 - Train Accuracy: 0.5164, Validation Accuracy: 0.4967, Loss: 0.7979 elapsed_time = 3.3 min
# Epoch   0 Batch  910/4308 - Train Accuracy: 0.5328, Validation Accuracy: 0.5148, Loss: 0.7789 elapsed_time = 3.4 min
# Epoch   0 Batch  920/4308 - Train Accuracy: 0.6302, Validation Accuracy: 0.4737, Loss: 0.7801 elapsed_time = 3.4 min
# Epoch   0 Batch  930/4308 - Train Accuracy: 0.5559, Validation Accuracy: 0.5296, Loss: 0.7897 elapsed_time = 3.5 min
# Epoch   0 Batch  940/4308 - Train Accuracy: 0.5087, Validation Accuracy: 0.4737, Loss: 0.9210 elapsed_time = 3.5 min
# Epoch   0 Batch  950/4308 - Train Accuracy: 0.4734, Validation Accuracy: 0.4885, Loss: 0.7345 elapsed_time = 3.6 min
# Epoch   0 Batch  960/4308 - Train Accuracy: 0.5938, Validation Accuracy: 0.5395, Loss: 0.7251 elapsed_time = 3.6 min
# Epoch   0 Batch  970/4308 - Train Accuracy: 0.6447, Validation Accuracy: 0.5378, Loss: 0.6978 elapsed_time = 3.7 min
# Epoch   0 Batch  980/4308 - Train Accuracy: 0.6344, Validation Accuracy: 0.5148, Loss: 0.7760 elapsed_time = 3.7 min
# Epoch   0 Batch  990/4308 - Train Accuracy: 0.5329, Validation Accuracy: 0.4918, Loss: 0.8447 elapsed_time = 3.8 min
# Epoch   0 Batch 1000/4308 - Train Accuracy: 0.5576, Validation Accuracy: 0.5197, Loss: 0.7139 elapsed_time = 3.8 min
# Epoch   0 Batch 1220/4308 - Train Accuracy: 0.5503, Validation Accuracy: 0.5296, Loss: 0.7174 elapsed_time = 4.8 min
# Epoch   0 Batch 1230/4308 - Train Accuracy: 0.6484, Validation Accuracy: 0.5181, Loss: 0.6556 elapsed_time = 4.8 min
# Epoch   0 Batch 1240/4308 - Train Accuracy: 0.6053, Validation Accuracy: 0.5280, Loss: 0.6499 elapsed_time = 4.9 min
# Epoch   0 Batch 1250/4308 - Train Accuracy: 0.6826, Validation Accuracy: 0.5378, Loss: 0.6484 elapsed_time = 4.9 min
# Epoch   0 Batch 1260/4308 - Train Accuracy: 0.6266, Validation Accuracy: 0.5625, Loss: 0.6477 elapsed_time = 4.9 min
# Epoch   0 Batch 1270/4308 - Train Accuracy: 0.6190, Validation Accuracy: 0.5362, Loss: 0.6058 elapsed_time = 5.0 min
# Epoch   0 Batch 1280/4308 - Train Accuracy: 0.6299, Validation Accuracy: 0.5263, Loss: 0.6164 elapsed_time = 5.0 min
# Epoch   0 Batch 1290/4308 - Train Accuracy: 0.6469, Validation Accuracy: 0.5395, Loss: 0.5554 elapsed_time = 5.0 min
# Epoch   0 Batch 1300/4308 - Train Accuracy: 0.6118, Validation Accuracy: 0.5132, Loss: 0.5895 elapsed_time = 5.1 min
# Epoch   0 Batch 1310/4308 - Train Accuracy: 0.6102, Validation Accuracy: 0.4819, Loss: 0.6261 elapsed_time = 5.1 min
# Epoch   0 Batch 1320/4308 - Train Accuracy: 0.6562, Validation Accuracy: 0.4901, Loss: 0.6552 elapsed_time = 5.1 min
# Epoch   0 Batch 1330/4308 - Train Accuracy: 0.6562, Validation Accuracy: 0.5148, Loss: 0.6446 elapsed_time = 5.2 min
# Epoch   0 Batch 1340/4308 - Train Accuracy: 0.6172, Validation Accuracy: 0.4720, Loss: 0.6089 elapsed_time = 5.2 min
# Epoch   0 Batch 1350/4308 - Train Accuracy: 0.6513, Validation Accuracy: 0.5214, Loss: 0.5731 elapsed_time = 5.3 min
# Epoch   0 Batch 1360/4308 - Train Accuracy: 0.6109, Validation Accuracy: 0.5263, Loss: 0.5857 elapsed_time = 5.3 min
# Epoch   0 Batch 1370/4308 - Train Accuracy: 0.6826, Validation Accuracy: 0.5444, Loss: 0.6888 elapsed_time = 5.3 min
# Epoch   0 Batch 1380/4308 - Train Accuracy: 0.6645, Validation Accuracy: 0.5362, Loss: 0.6246 elapsed_time = 5.4 min
# Epoch   0 Batch 1390/4308 - Train Accuracy: 0.5888, Validation Accuracy: 0.5592, Loss: 0.6272 elapsed_time = 5.4 min
# Epoch   0 Batch 1400/4308 - Train Accuracy: 0.5280, Validation Accuracy: 0.5280, Loss: 0.6463 elapsed_time = 5.4 min
# Epoch   0 Batch 1410/4308 - Train Accuracy: 0.5461, Validation Accuracy: 0.5345, Loss: 0.5948 elapsed_time = 5.5 min
# Epoch   0 Batch 1420/4308 - Train Accuracy: 0.6672, Validation Accuracy: 0.5263, Loss: 0.6655 elapsed_time = 5.5 min
# Epoch   0 Batch 2070/4308 - Train Accuracy: 0.7434, Validation Accuracy: 0.6299, Loss: 0.4647 elapsed_time = 7.7 min
# Epoch   0 Batch 2080/4308 - Train Accuracy: 0.7270, Validation Accuracy: 0.6530, Loss: 0.4522 elapsed_time = 7.7 min
# Epoch   0 Batch 2090/4308 - Train Accuracy: 0.6497, Validation Accuracy: 0.6447, Loss: 0.4428 elapsed_time = 7.8 min
# Epoch   0 Batch 2100/4308 - Train Accuracy: 0.7171, Validation Accuracy: 0.6480, Loss: 0.4346 elapsed_time = 7.8 min
# Epoch   0 Batch 2110/4308 - Train Accuracy: 0.7281, Validation Accuracy: 0.6809, Loss: 0.3877 elapsed_time = 7.8 min
# Epoch   0 Batch 2120/4308 - Train Accuracy: 0.7375, Validation Accuracy: 0.6497, Loss: 0.3981 elapsed_time = 7.9 min
# Epoch   0 Batch 2130/4308 - Train Accuracy: 0.6906, Validation Accuracy: 0.6398, Loss: 0.4043 elapsed_time = 7.9 min
# Epoch   0 Batch 2140/4308 - Train Accuracy: 0.7418, Validation Accuracy: 0.7007, Loss: 0.4422 elapsed_time = 7.9 min
# Epoch   0 Batch 2150/4308 - Train Accuracy: 0.7138, Validation Accuracy: 0.6743, Loss: 0.4413 elapsed_time = 8.0 min
# Epoch   0 Batch 2160/4308 - Train Accuracy: 0.7089, Validation Accuracy: 0.6760, Loss: 0.4447 elapsed_time = 8.0 min
# Epoch   0 Batch 2170/4308 - Train Accuracy: 0.7105, Validation Accuracy: 0.6447, Loss: 0.4149 elapsed_time = 8.0 min
# Epoch   0 Batch 2180/4308 - Train Accuracy: 0.6797, Validation Accuracy: 0.6562, Loss: 0.3492 elapsed_time = 8.1 min
# Epoch   0 Batch 2190/4308 - Train Accuracy: 0.7297, Validation Accuracy: 0.6612, Loss: 0.4109 elapsed_time = 8.1 min
# Epoch   0 Batch 2200/4308 - Train Accuracy: 0.6908, Validation Accuracy: 0.6316, Loss: 0.4558 elapsed_time = 8.1 min
# Epoch   0 Batch 2210/4308 - Train Accuracy: 0.7125, Validation Accuracy: 0.6316, Loss: 0.4219 elapsed_time = 8.2 min
# Epoch   0 Batch 2220/4308 - Train Accuracy: 0.7418, Validation Accuracy: 0.6118, Loss: 0.3850 elapsed_time = 8.2 min
# Epoch   0 Batch 2230/4308 - Train Accuracy: 0.7141, Validation Accuracy: 0.6201, Loss: 0.3940 elapsed_time = 8.2 min
# Epoch   0 Batch 2240/4308 - Train Accuracy: 0.7763, Validation Accuracy: 0.6562, Loss: 0.4143 elapsed_time = 8.3 min
# Epoch   0 Batch 2250/4308 - Train Accuracy: 0.7750, Validation Accuracy: 0.6135, Loss: 0.3829 elapsed_time = 8.3 min
# Epoch   0 Batch 2260/4308 - Train Accuracy: 0.7326, Validation Accuracy: 0.6316, Loss: 0.4812 elapsed_time = 8.3 min
# Epoch   0 Batch 2270/4308 - Train Accuracy: 0.7336, Validation Accuracy: 0.6809, Loss: 0.3686 elapsed_time = 8.4 min
# Epoch   0 Batch 2710/4308 - Train Accuracy: 0.8125, Validation Accuracy: 0.7368, Loss: 0.2794 elapsed_time = 9.9 min
# Epoch   0 Batch 2720/4308 - Train Accuracy: 0.7944, Validation Accuracy: 0.7878, Loss: 0.3582 elapsed_time = 9.9 min
# Epoch   0 Batch 2730/4308 - Train Accuracy: 0.8313, Validation Accuracy: 0.7072, Loss: 0.2902 elapsed_time = 9.9 min
# Epoch   0 Batch 2740/4308 - Train Accuracy: 0.8516, Validation Accuracy: 0.7549, Loss: 0.2803 elapsed_time = 10.0 min
# Epoch   0 Batch 2750/4308 - Train Accuracy: 0.7862, Validation Accuracy: 0.7484, Loss: 0.3107 elapsed_time = 10.0 min
# Epoch   0 Batch 2760/4308 - Train Accuracy: 0.7961, Validation Accuracy: 0.7993, Loss: 0.2604 elapsed_time = 10.1 min
# Epoch   0 Batch 2770/4308 - Train Accuracy: 0.7615, Validation Accuracy: 0.7270, Loss: 0.3368 elapsed_time = 10.1 min
# Epoch   0 Batch 2780/4308 - Train Accuracy: 0.8043, Validation Accuracy: 0.7697, Loss: 0.3126 elapsed_time = 10.1 min
# Epoch   0 Batch 2790/4308 - Train Accuracy: 0.7697, Validation Accuracy: 0.7829, Loss: 0.3488 elapsed_time = 10.2 min
# Epoch   0 Batch 2800/4308 - Train Accuracy: 0.8207, Validation Accuracy: 0.7993, Loss: 0.2892 elapsed_time = 10.2 min
# Epoch   0 Batch 2810/4308 - Train Accuracy: 0.7253, Validation Accuracy: 0.7895, Loss: 0.3093 elapsed_time = 10.2 min
# Epoch   0 Batch 2820/4308 - Train Accuracy: 0.7747, Validation Accuracy: 0.7961, Loss: 0.2999 elapsed_time = 10.3 min
# Epoch   0 Batch 2830/4308 - Train Accuracy: 0.7781, Validation Accuracy: 0.8421, Loss: 0.2804 elapsed_time = 10.3 min
# Epoch   0 Batch 2840/4308 - Train Accuracy: 0.7465, Validation Accuracy: 0.7862, Loss: 0.3085 elapsed_time = 10.3 min
# Epoch   0 Batch 2850/4308 - Train Accuracy: 0.8224, Validation Accuracy: 0.7928, Loss: 0.3227 elapsed_time = 10.4 min
# Epoch   0 Batch 2860/4308 - Train Accuracy: 0.8109, Validation Accuracy: 0.7747, Loss: 0.2819 elapsed_time = 10.4 min
# Epoch   0 Batch 2870/4308 - Train Accuracy: 0.8031, Validation Accuracy: 0.7747, Loss: 0.2642 elapsed_time = 10.4 min
# Epoch   0 Batch 2880/4308 - Train Accuracy: 0.7753, Validation Accuracy: 0.7467, Loss: 0.2711 elapsed_time = 10.5 min
# Epoch   0 Batch 2890/4308 - Train Accuracy: 0.8484, Validation Accuracy: 0.7862, Loss: 0.2795 elapsed_time = 10.5 min
# Epoch   0 Batch 2900/4308 - Train Accuracy: 0.8142, Validation Accuracy: 0.8109, Loss: 0.3292 elapsed_time = 10.5 min
# Epoch   0 Batch 2910/4308 - Train Accuracy: 0.8766, Validation Accuracy: 0.7516, Loss: 0.2561 elapsed_time = 10.6 min
# Epoch   0 Batch 2920/4308 - Train Accuracy: 0.7763, Validation Accuracy: 0.7911, Loss: 0.2313 elapsed_time = 10.6 min
# Epoch   0 Batch 2930/4308 - Train Accuracy: 0.7708, Validation Accuracy: 0.8174, Loss: 0.2593 elapsed_time = 10.6 min
# Epoch   0 Batch 2940/4308 - Train Accuracy: 0.8487, Validation Accuracy: 0.8043, Loss: 0.2911 elapsed_time = 10.7 min
# Epoch   0 Batch 2950/4308 - Train Accuracy: 0.8010, Validation Accuracy: 0.7237, Loss: 0.2480 elapsed_time = 10.7 min
# Epoch   0 Batch 2960/4308 - Train Accuracy: 0.8734, Validation Accuracy: 0.7582, Loss: 0.2396 elapsed_time = 10.7 min
# Epoch   0 Batch 2970/4308 - Train Accuracy: 0.8569, Validation Accuracy: 0.8010, Loss: 0.2418 elapsed_time = 10.8 min
# Epoch   0 Batch 2980/4308 - Train Accuracy: 0.8844, Validation Accuracy: 0.7895, Loss: 0.2104 elapsed_time = 10.8 min
# Epoch   0 Batch 2990/4308 - Train Accuracy: 0.8306, Validation Accuracy: 0.7862, Loss: 0.2634 elapsed_time = 10.8 min
# Epoch   0 Batch 3000/4308 - Train Accuracy: 0.7594, Validation Accuracy: 0.7763, Loss: 0.2790 elapsed_time = 10.9 min
# Epoch   0 Batch 3010/4308 - Train Accuracy: 0.8207, Validation Accuracy: 0.8421, Loss: 0.2391 elapsed_time = 10.9 min
# Epoch   0 Batch 3020/4308 - Train Accuracy: 0.8594, Validation Accuracy: 0.7993, Loss: 0.2443 elapsed_time = 10.9 min
# Epoch   0 Batch 3030/4308 - Train Accuracy: 0.8031, Validation Accuracy: 0.8421, Loss: 0.2295 elapsed_time = 11.0 min
# Epoch   0 Batch 3040/4308 - Train Accuracy: 0.7878, Validation Accuracy: 0.7911, Loss: 0.2624 elapsed_time = 11.0 min
# Epoch   0 Batch 3050/4308 - Train Accuracy: 0.7714, Validation Accuracy: 0.8109, Loss: 0.2117 elapsed_time = 11.0 min
# Epoch   0 Batch 3060/4308 - Train Accuracy: 0.9062, Validation Accuracy: 0.8092, Loss: 0.2201 elapsed_time = 11.1 min
# Epoch   0 Batch 3070/4308 - Train Accuracy: 0.8219, Validation Accuracy: 0.8503, Loss: 0.2182 elapsed_time = 11.1 min
# Epoch   0 Batch 3080/4308 - Train Accuracy: 0.8191, Validation Accuracy: 0.7796, Loss: 0.2882 elapsed_time = 11.1 min
# Epoch   0 Batch 3090/4308 - Train Accuracy: 0.8010, Validation Accuracy: 0.8651, Loss: 0.2952 elapsed_time = 11.2 min
# Epoch   0 Batch 3100/4308 - Train Accuracy: 0.8553, Validation Accuracy: 0.8372, Loss: 0.2534 elapsed_time = 11.2 min
# Epoch   0 Batch 3110/4308 - Train Accuracy: 0.9046, Validation Accuracy: 0.7944, Loss: 0.2208 elapsed_time = 11.2 min
# Epoch   0 Batch 3120/4308 - Train Accuracy: 0.8454, Validation Accuracy: 0.7993, Loss: 0.2035 elapsed_time = 11.3 min
# Epoch   0 Batch 3340/4308 - Train Accuracy: 0.8608, Validation Accuracy: 0.8520, Loss: 0.2015 elapsed_time = 12.0 min
# Epoch   0 Batch 3350/4308 - Train Accuracy: 0.8470, Validation Accuracy: 0.8553, Loss: 0.2015 elapsed_time = 12.1 min
# Epoch   0 Batch 3360/4308 - Train Accuracy: 0.8859, Validation Accuracy: 0.8602, Loss: 0.1880 elapsed_time = 12.1 min
# Epoch   0 Batch 3370/4308 - Train Accuracy: 0.8906, Validation Accuracy: 0.8289, Loss: 0.1631 elapsed_time = 12.1 min
# Epoch   0 Batch 3380/4308 - Train Accuracy: 0.8832, Validation Accuracy: 0.8750, Loss: 0.1654 elapsed_time = 12.2 min
# Epoch   0 Batch 3390/4308 - Train Accuracy: 0.8931, Validation Accuracy: 0.9013, Loss: 0.1715 elapsed_time = 12.2 min
# Epoch   0 Batch 3400/4308 - Train Accuracy: 0.8406, Validation Accuracy: 0.8668, Loss: 0.1660 elapsed_time = 12.2 min
# Epoch   0 Batch 3410/4308 - Train Accuracy: 0.8051, Validation Accuracy: 0.8536, Loss: 0.2433 elapsed_time = 12.3 min
# Epoch   0 Batch 3420/4308 - Train Accuracy: 0.8026, Validation Accuracy: 0.8964, Loss: 0.2208 elapsed_time = 12.3 min
# Epoch   0 Batch 3430/4308 - Train Accuracy: 0.9062, Validation Accuracy: 0.8766, Loss: 0.1810 elapsed_time = 12.3 min
# Epoch   0 Batch 3440/4308 - Train Accuracy: 0.8158, Validation Accuracy: 0.8717, Loss: 0.2689 elapsed_time = 12.4 min
# Epoch   0 Batch 3450/4308 - Train Accuracy: 0.9112, Validation Accuracy: 0.8257, Loss: 0.1717 elapsed_time = 12.4 min
# Epoch   0 Batch 3460/4308 - Train Accuracy: 0.8141, Validation Accuracy: 0.8026, Loss: 0.2003 elapsed_time = 12.4 min
# Epoch   0 Batch 3470/4308 - Train Accuracy: 0.8520, Validation Accuracy: 0.8125, Loss: 0.1920 elapsed_time = 12.5 min
# Epoch   0 Batch 3480/4308 - Train Accuracy: 0.8047, Validation Accuracy: 0.8438, Loss: 0.2136 elapsed_time = 12.5 min
# Epoch   0 Batch 3490/4308 - Train Accuracy: 0.8406, Validation Accuracy: 0.8849, Loss: 0.1837 elapsed_time = 12.5 min
# Epoch   0 Batch 3500/4308 - Train Accuracy: 0.8203, Validation Accuracy: 0.8618, Loss: 0.2171 elapsed_time = 12.6 min
# Epoch   0 Batch 3510/4308 - Train Accuracy: 0.8859, Validation Accuracy: 0.8487, Loss: 0.1800 elapsed_time = 12.6 min
# Epoch   0 Batch 3520/4308 - Train Accuracy: 0.8733, Validation Accuracy: 0.7829, Loss: 0.1765 elapsed_time = 12.6 min
# Epoch   0 Batch 3530/4308 - Train Accuracy: 0.8322, Validation Accuracy: 0.7977, Loss: 0.1661 elapsed_time = 12.7 min
# Epoch   0 Batch 3540/4308 - Train Accuracy: 0.8717, Validation Accuracy: 0.8914, Loss: 0.1581 elapsed_time = 12.7 min
# Epoch   0 Batch 3550/4308 - Train Accuracy: 0.8703, Validation Accuracy: 0.8586, Loss: 0.1448 elapsed_time = 12.7 min
# Epoch   0 Batch 3560/4308 - Train Accuracy: 0.8799, Validation Accuracy: 0.7911, Loss: 0.1869 elapsed_time = 12.8 min
# Epoch   0 Batch 3570/4308 - Train Accuracy: 0.9260, Validation Accuracy: 0.9260, Loss: 0.1397 elapsed_time = 12.8 min
# Epoch   0 Batch 3580/4308 - Train Accuracy: 0.8420, Validation Accuracy: 0.8701, Loss: 0.2227 elapsed_time = 12.8 min
# Epoch   0 Batch 3590/4308 - Train Accuracy: 0.9161, Validation Accuracy: 0.9342, Loss: 0.1433 elapsed_time = 12.9 min
# Epoch   0 Batch 3600/4308 - Train Accuracy: 0.9062, Validation Accuracy: 0.9375, Loss: 0.1944 elapsed_time = 12.9 min
# Epoch   0 Batch 3610/4308 - Train Accuracy: 0.8988, Validation Accuracy: 0.8734, Loss: 0.1644 elapsed_time = 12.9 min
# Epoch   0 Batch 3620/4308 - Train Accuracy: 0.9194, Validation Accuracy: 0.8931, Loss: 0.1494 elapsed_time = 13.0 min
# Epoch   0 Batch 3630/4308 - Train Accuracy: 0.7796, Validation Accuracy: 0.8339, Loss: 0.1453 elapsed_time = 13.0 min
# Epoch   0 Batch 3640/4308 - Train Accuracy: 0.8503, Validation Accuracy: 0.8339, Loss: 0.1607 elapsed_time = 13.0 min
# Epoch   0 Batch 3650/4308 - Train Accuracy: 0.8580, Validation Accuracy: 0.9194, Loss: 0.1351 elapsed_time = 13.1 min
# Epoch   0 Batch 3660/4308 - Train Accuracy: 0.8569, Validation Accuracy: 0.8750, Loss: 0.1679 elapsed_time = 13.1 min
# Epoch   0 Batch 3670/4308 - Train Accuracy: 0.8849, Validation Accuracy: 0.9326, Loss: 0.1477 elapsed_time = 13.1 min
# Epoch   0 Batch 3680/4308 - Train Accuracy: 0.9293, Validation Accuracy: 0.9079, Loss: 0.1370 elapsed_time = 13.2 min
# Epoch   0 Batch 3690/4308 - Train Accuracy: 0.9156, Validation Accuracy: 0.8914, Loss: 0.1196 elapsed_time = 13.2 min
# Epoch   0 Batch 3700/4308 - Train Accuracy: 0.8766, Validation Accuracy: 0.8635, Loss: 0.1287 elapsed_time = 13.2 min
# Epoch   0 Batch 3710/4308 - Train Accuracy: 0.8172, Validation Accuracy: 0.8832, Loss: 0.1627 elapsed_time = 13.3 min
# Epoch   0 Batch 3720/4308 - Train Accuracy: 0.8766, Validation Accuracy: 0.9112, Loss: 0.1761 elapsed_time = 13.3 min
# Epoch   0 Batch 3730/4308 - Train Accuracy: 0.9016, Validation Accuracy: 0.8487, Loss: 0.1272 elapsed_time = 13.3 min
# Epoch   0 Batch 3740/4308 - Train Accuracy: 0.8750, Validation Accuracy: 0.8849, Loss: 0.1569 elapsed_time = 13.4 min
# Epoch   0 Batch 3750/4308 - Train Accuracy: 0.9196, Validation Accuracy: 0.9046, Loss: 0.1636 elapsed_time = 13.4 min
# Epoch   0 Batch 3760/4308 - Train Accuracy: 0.9178, Validation Accuracy: 0.9507, Loss: 0.1636 elapsed_time = 13.4 min
# Epoch   0 Batch 3770/4308 - Train Accuracy: 0.8906, Validation Accuracy: 0.8322, Loss: 0.1594 elapsed_time = 13.5 min
# Epoch   0 Batch 3780/4308 - Train Accuracy: 0.8512, Validation Accuracy: 0.9260, Loss: 0.1433 elapsed_time = 13.5 min
# Epoch   0 Batch 3790/4308 - Train Accuracy: 0.8586, Validation Accuracy: 0.9309, Loss: 0.1542 elapsed_time = 13.6 min
# Epoch   0 Batch 3800/4308 - Train Accuracy: 0.8947, Validation Accuracy: 0.8421, Loss: 0.1408 elapsed_time = 13.6 min
# Epoch   0 Batch 3810/4308 - Train Accuracy: 0.9046, Validation Accuracy: 0.9342, Loss: 0.1681 elapsed_time = 13.6 min
# Epoch   0 Batch 3820/4308 - Train Accuracy: 0.8828, Validation Accuracy: 0.8865, Loss: 0.2060 elapsed_time = 13.7 min
# Epoch   0 Batch 3830/4308 - Train Accuracy: 0.9408, Validation Accuracy: 0.9128, Loss: 0.1255 elapsed_time = 13.7 min
# Epoch   0 Batch 3840/4308 - Train Accuracy: 0.9031, Validation Accuracy: 0.9079, Loss: 0.1388 elapsed_time = 13.7 min
# Epoch   0 Batch 3850/4308 - Train Accuracy: 0.8922, Validation Accuracy: 0.8454, Loss: 0.1341 elapsed_time = 13.8 min
# Epoch   0 Batch 3860/4308 - Train Accuracy: 0.7944, Validation Accuracy: 0.9062, Loss: 0.1462 elapsed_time = 13.8 min
# Epoch   0 Batch 3870/4308 - Train Accuracy: 0.9360, Validation Accuracy: 0.9556, Loss: 0.0879 elapsed_time = 13.8 min
# Epoch   0 Batch 3880/4308 - Train Accuracy: 0.8766, Validation Accuracy: 0.8980, Loss: 0.2395 elapsed_time = 13.9 min
# Epoch   0 Batch 3890/4308 - Train Accuracy: 0.8586, Validation Accuracy: 0.8997, Loss: 0.1680 elapsed_time = 13.9 min
# Epoch   0 Batch 3900/4308 - Train Accuracy: 0.8602, Validation Accuracy: 0.9079, Loss: 0.1194 elapsed_time = 13.9 min
# Epoch   0 Batch 3910/4308 - Train Accuracy: 0.8668, Validation Accuracy: 0.8372, Loss: 0.1466 elapsed_time = 14.0 min
# Epoch   0 Batch 3920/4308 - Train Accuracy: 0.8816, Validation Accuracy: 0.9408, Loss: 0.0985 elapsed_time = 14.0 min
# Epoch   0 Batch 3930/4308 - Train Accuracy: 0.9109, Validation Accuracy: 0.9211, Loss: 0.1199 elapsed_time = 14.0 min
# Epoch   0 Batch 3940/4308 - Train Accuracy: 0.8602, Validation Accuracy: 0.8997, Loss: 0.1854 elapsed_time = 14.1 min
# Epoch   0 Batch 3950/4308 - Train Accuracy: 0.8703, Validation Accuracy: 0.9030, Loss: 0.1419 elapsed_time = 14.1 min
# Epoch   0 Batch 3960/4308 - Train Accuracy: 0.8891, Validation Accuracy: 0.8717, Loss: 0.1430 elapsed_time = 14.1 min
# Epoch   0 Batch 3970/4308 - Train Accuracy: 0.8938, Validation Accuracy: 0.8355, Loss: 0.1153 elapsed_time = 14.2 min
# Epoch   0 Batch 3980/4308 - Train Accuracy: 0.9161, Validation Accuracy: 0.9095, Loss: 0.1376 elapsed_time = 14.2 min
# Epoch   0 Batch 3990/4308 - Train Accuracy: 0.9309, Validation Accuracy: 0.9112, Loss: 0.1318 elapsed_time = 14.2 min
# Epoch   0 Batch 4000/4308 - Train Accuracy: 0.9167, Validation Accuracy: 0.9145, Loss: 0.1309 elapsed_time = 14.3 min
# Epoch   0 Batch 4010/4308 - Train Accuracy: 0.9219, Validation Accuracy: 0.8536, Loss: 0.1168 elapsed_time = 14.3 min
# Epoch   0 Batch 4020/4308 - Train Accuracy: 0.9703, Validation Accuracy: 0.9161, Loss: 0.0963 elapsed_time = 14.3 min
# Epoch   0 Batch 4030/4308 - Train Accuracy: 0.8997, Validation Accuracy: 0.8882, Loss: 0.1253 elapsed_time = 14.4 min
# Epoch   0 Batch 4040/4308 - Train Accuracy: 0.9484, Validation Accuracy: 0.9112, Loss: 0.0967 elapsed_time = 14.4 min
# Epoch   0 Batch 4050/4308 - Train Accuracy: 0.8980, Validation Accuracy: 0.9178, Loss: 0.1220 elapsed_time = 14.4 min
# Epoch   0 Batch 4060/4308 - Train Accuracy: 0.8470, Validation Accuracy: 0.9161, Loss: 0.1625 elapsed_time = 14.5 min
# Epoch   0 Batch 4070/4308 - Train Accuracy: 0.8405, Validation Accuracy: 0.8931, Loss: 0.1162 elapsed_time = 14.5 min
# Epoch   0 Batch 4080/4308 - Train Accuracy: 0.8816, Validation Accuracy: 0.8355, Loss: 0.1457 elapsed_time = 14.5 min
# Epoch   0 Batch 4090/4308 - Train Accuracy: 0.8953, Validation Accuracy: 0.8684, Loss: 0.1386 elapsed_time = 14.6 min
# ...
# Epoch   9 Batch 2960/4308 - Train Accuracy: 0.9918, Validation Accuracy: 0.9967, Loss: 0.0048 elapsed_time = 89.8 min
# Epoch   9 Batch 2970/4308 - Train Accuracy: 0.9868, Validation Accuracy: 0.9770, Loss: 0.0038 elapsed_time = 89.8 min
# Epoch   9 Batch 2980/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9770, Loss: 0.0085 elapsed_time = 89.8 min
# Epoch   9 Batch 2990/4308 - Train Accuracy: 0.9984, Validation Accuracy: 0.9770, Loss: 0.0121 elapsed_time = 89.8 min
# Epoch   9 Batch 3000/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0039 elapsed_time = 89.9 min
# Epoch   9 Batch 3010/4308 - Train Accuracy: 0.9737, Validation Accuracy: 0.9967, Loss: 0.0090 elapsed_time = 89.9 min
# Epoch   9 Batch 3020/4308 - Train Accuracy: 0.9828, Validation Accuracy: 0.9967, Loss: 0.0124 elapsed_time = 89.9 min
# Epoch   9 Batch 3030/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0018 elapsed_time = 89.9 min
# Epoch   9 Batch 3040/4308 - Train Accuracy: 0.9868, Validation Accuracy: 0.9770, Loss: 0.0406 elapsed_time = 89.9 min
# Epoch   9 Batch 3050/4308 - Train Accuracy: 0.9753, Validation Accuracy: 0.9984, Loss: 0.0137 elapsed_time = 89.9 min
# Epoch   9 Batch 3060/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0077 elapsed_time = 89.9 min
# Epoch   9 Batch 3070/4308 - Train Accuracy: 0.9750, Validation Accuracy: 0.9984, Loss: 0.0036 elapsed_time = 90.0 min
# Epoch   9 Batch 3080/4308 - Train Accuracy: 0.9984, Validation Accuracy: 0.9984, Loss: 0.0068 elapsed_time = 90.0 min
# Epoch   9 Batch 3090/4308 - Train Accuracy: 0.9901, Validation Accuracy: 0.9984, Loss: 0.0090 elapsed_time = 90.0 min
# Epoch   9 Batch 3100/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0027 elapsed_time = 90.0 min
# Epoch   9 Batch 3110/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0022 elapsed_time = 90.0 min
# Epoch   9 Batch 3120/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0112 elapsed_time = 90.0 min
# Epoch   9 Batch 3130/4308 - Train Accuracy: 0.9934, Validation Accuracy: 0.9967, Loss: 0.0051 elapsed_time = 90.1 min
# Epoch   9 Batch 3140/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0040 elapsed_time = 90.1 min
# Epoch   9 Batch 3150/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0023 elapsed_time = 90.1 min
# Epoch   9 Batch 3160/4308 - Train Accuracy: 0.9984, Validation Accuracy: 0.9967, Loss: 0.0126 elapsed_time = 90.1 min
# Epoch   9 Batch 3170/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0025 elapsed_time = 90.1 min
# Epoch   9 Batch 3180/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0011 elapsed_time = 90.1 min
# Epoch   9 Batch 3190/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9688, Loss: 0.0076 elapsed_time = 90.2 min
# Epoch   9 Batch 3200/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9704, Loss: 0.0089 elapsed_time = 90.2 min
# Epoch   9 Batch 3210/4308 - Train Accuracy: 0.9984, Validation Accuracy: 0.9704, Loss: 0.0130 elapsed_time = 90.2 min
# Epoch   9 Batch 3220/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9918, Loss: 0.0040 elapsed_time = 90.2 min
# Epoch   9 Batch 3230/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9688, Loss: 0.0030 elapsed_time = 90.2 min
# Epoch   9 Batch 3240/4308 - Train Accuracy: 0.9720, Validation Accuracy: 0.9688, Loss: 0.0100 elapsed_time = 90.2 min
# Epoch   9 Batch 3250/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9753, Loss: 0.0020 elapsed_time = 90.3 min
# Epoch   9 Batch 3260/4308 - Train Accuracy: 0.9797, Validation Accuracy: 0.9704, Loss: 0.0090 elapsed_time = 90.3 min
# Epoch   9 Batch 3270/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0024 elapsed_time = 90.3 min
# Epoch   9 Batch 3280/4308 - Train Accuracy: 0.9781, Validation Accuracy: 0.9786, Loss: 0.0091 elapsed_time = 90.3 min
# Epoch   9 Batch 3290/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9786, Loss: 0.0179 elapsed_time = 90.3 min
# Epoch   9 Batch 3300/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0033 elapsed_time = 90.3 min
# Epoch   9 Batch 3310/4308 - Train Accuracy: 0.9757, Validation Accuracy: 0.9984, Loss: 0.0104 elapsed_time = 90.4 min
# Epoch   9 Batch 3320/4308 - Train Accuracy: 0.9656, Validation Accuracy: 0.9984, Loss: 0.0227 elapsed_time = 90.4 min
# Epoch   9 Batch 3330/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0087 elapsed_time = 90.4 min
# Epoch   9 Batch 3340/4308 - Train Accuracy: 0.9787, Validation Accuracy: 0.9967, Loss: 0.0098 elapsed_time = 90.4 min
# Epoch   9 Batch 3350/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0039 elapsed_time = 90.4 min
# Epoch   9 Batch 3360/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0046 elapsed_time = 90.4 min
# Epoch   9 Batch 3370/4308 - Train Accuracy: 0.9781, Validation Accuracy: 0.9967, Loss: 0.0135 elapsed_time = 90.5 min
# Epoch   9 Batch 3380/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0021 elapsed_time = 90.5 min
# Epoch   9 Batch 3390/4308 - Train Accuracy: 0.9589, Validation Accuracy: 0.9984, Loss: 0.0165 elapsed_time = 90.5 min
# Epoch   9 Batch 3400/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0042 elapsed_time = 90.5 min
# Epoch   9 Batch 3410/4308 - Train Accuracy: 0.9360, Validation Accuracy: 0.9951, Loss: 0.0092 elapsed_time = 90.5 min
# Epoch   9 Batch 3420/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9951, Loss: 0.0219 elapsed_time = 90.5 min
# Epoch   9 Batch 3430/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0029 elapsed_time = 90.6 min
# Epoch   9 Batch 3440/4308 - Train Accuracy: 0.9934, Validation Accuracy: 0.9967, Loss: 0.0143 elapsed_time = 90.6 min
# Epoch   9 Batch 3450/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0138 elapsed_time = 90.6 min
# Epoch   9 Batch 3460/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0042 elapsed_time = 90.6 min
# Epoch   9 Batch 3470/4308 - Train Accuracy: 0.9951, Validation Accuracy: 0.9984, Loss: 0.0168 elapsed_time = 90.6 min
# Epoch   9 Batch 3480/4308 - Train Accuracy: 0.9906, Validation Accuracy: 0.9984, Loss: 0.0100 elapsed_time = 90.6 min
# Epoch   9 Batch 3490/4308 - Train Accuracy: 0.9844, Validation Accuracy: 0.9984, Loss: 0.0179 elapsed_time = 90.7 min
# Epoch   9 Batch 3500/4308 - Train Accuracy: 0.9844, Validation Accuracy: 0.9984, Loss: 0.0071 elapsed_time = 90.7 min
# Epoch   9 Batch 3510/4308 - Train Accuracy: 0.9891, Validation Accuracy: 0.9967, Loss: 0.0185 elapsed_time = 90.7 min
# Epoch   9 Batch 3520/4308 - Train Accuracy: 0.9861, Validation Accuracy: 0.9951, Loss: 0.0087 elapsed_time = 90.7 min
# Epoch   9 Batch 3530/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0029 elapsed_time = 90.7 min
# Epoch   9 Batch 3540/4308 - Train Accuracy: 0.9523, Validation Accuracy: 0.9984, Loss: 0.0143 elapsed_time = 90.7 min
# Epoch   9 Batch 3550/4308 - Train Accuracy: 0.9703, Validation Accuracy: 0.9967, Loss: 0.0119 elapsed_time = 90.8 min
# Epoch   9 Batch 3560/4308 - Train Accuracy: 0.9655, Validation Accuracy: 0.9984, Loss: 0.0132 elapsed_time = 90.8 min
# Epoch   9 Batch 3570/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9967, Loss: 0.0019 elapsed_time = 90.8 min
# Epoch   9 Batch 3580/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0058 elapsed_time = 90.8 min
# Epoch   9 Batch 3590/4308 - Train Accuracy: 0.9967, Validation Accuracy: 0.9984, Loss: 0.0068 elapsed_time = 90.8 min
# Epoch   9 Batch 3600/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.
4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0041 elapsed_time = 91.3 min
# Epoch   9 Batch 3870/4308 - Train Accuracy: 0.9792, Validation Accuracy: 0.9984, Loss: 0.0034 elapsed_time = 91.3 min
# Epoch   9 Batch 3880/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0258 elapsed_time = 91.3 min
# Epoch   9 Batch 3890/4308 - Train Accuracy: 0.9753, Validation Accuracy: 0.9984, Loss: 0.0138 elapsed_time = 91.3 min
# Epoch   9 Batch 3900/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0038 elapsed_time = 91.3 min
# Epoch   9 Batch 3910/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0104 elapsed_time = 91.4 min
# Epoch   9 Batch 3920/4308 - Train Accuracy: 0.9803, Validation Accuracy: 0.9984, Loss: 0.0188 elapsed_time = 91.4 min
# Epoch   9 Batch 3930/4308 - Train Accuracy: 0.9766, Validation Accuracy: 0.9984, Loss: 0.0094 elapsed_time = 91.4 min
# Epoch   9 Batch 3940/4308 - Train Accuracy: 0.9786, Validation Accuracy: 0.9786, Loss: 0.0059 elapsed_time = 91.4 min
# Epoch   9 Batch 3950/4308 - Train Accuracy: 0.9547, Validation Accuracy: 0.9786, Loss: 0.0096 elapsed_time = 91.4 min
# Epoch   9 Batch 3960/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9786, Loss: 0.0057 elapsed_time = 91.4 min
# Epoch   9 Batch 3970/4308 - Train Accuracy: 0.9969, Validation Accuracy: 0.9786, Loss: 0.0156 elapsed_time = 91.5 min
# Epoch   9 Batch 3980/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9786, Loss: 0.0123 elapsed_time = 91.5 min
# Epoch   9 Batch 3990/4308 - Train Accuracy: 0.9984, Validation Accuracy: 0.9984, Loss: 0.0116 elapsed_time = 91.5 min
# Epoch   9 Batch 4000/4308 - Train Accuracy: 0.9757, Validation Accuracy: 0.9984, Loss: 0.0098 elapsed_time = 91.5 min
# Epoch   9 Batch 4010/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9984, Loss: 0.0060 elapsed_time = 91.5 min
# Epoch   9 Batch 4020/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9786, Loss: 0.0060 elapsed_time = 91.5 min
# Epoch   9 Batch 4030/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9770, Loss: 0.0025 elapsed_time = 91.6 min
# Epoch   9 Batch 4040/4308 - Train Accuracy: 1.0000, Validation Accuracy: 0.9951, Loss: 0.0056 elapsed_time = 91.6 min
# Epoch   9 Batch 4050/4308 - Train Accuracy: 0.9622, Validation Accuracy: 0.9967, Loss: 0.0105 elapsed_time = 91.6 min
# Epoch   9 Batch 4060/4308 - Train Accuracy: 0.9375, Validation Accuracy: 0.9984, Loss: 0.0111 elapsed_time = 91.6 min
# Epoch   9 Batch 4070/4308 - Train Accuracy: 0.9984, Validation Accuracy: 0.9984, Loss: 0.0115 elapsed_time = 91.6 min
# Epoch   9 Batch 4080/4308 - Train Accuracy: 0.9885, Validation Accuracy: 1.0000, Loss: 0.0220 elapsed_time = 91.6 min
